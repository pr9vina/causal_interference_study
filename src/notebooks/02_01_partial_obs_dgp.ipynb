# %%
# %reload_ext autoreload

import numpy as np
import pickle
import pandas as pd
from collections import defaultdict

from data_generation.network_generator import StochasticBlockModel
from data_generation.data_simulator import IndividualDataSimulator
from constants import NetworkSettings, DataGenerationSettings
from data_generation.data_generator_main import run_data_simulations
from methods.methods_est import LinearRegressionEstimator
from methods.visualization import ResultsPlotter

# %%
network_settings = NetworkSettings()
dgp_settings = DataGenerationSettings()

# %%
results = run_data_simulations(
    assignment_types=dgp_settings.assignment_types,
    treatment_effects=dgp_settings.treatment_effects,
    network_configs=network_settings.networks_types,
    neighbour_influences=dgp_settings.n_influence_list,
    n_nodes=network_settings.n_nodes,
    n_features=dgp_settings.n_features,
    error_mean=dgp_settings.error_mean,
    error_std=dgp_settings.error_std,
    beta_mean=dgp_settings.beta_mean,
    beta_std=dgp_settings.beta_std,
    share_treatment=dgp_settings.share_treatment,
    n_edges=network_settings.n_edges,
    n_sim=dgp_settings.n_sim,
    add_network_features=True,
    add_embeddings=True,
    add_count_treated=True,
    network_structure_type="random",
    dimensions=network_settings.vec_dimensions,
    walk_length=network_settings.vec_walk_length,
    num_walks=network_settings.vec_num_walks,
    p_random_walk=network_settings.p_random_walk,
    q_random_walk=network_settings.q_random_walk,
    vec_window=network_settings.vec_window,
    min_count=network_settings.min_count,
    batch_words=network_settings.batch_words,
    corrupt_network=True,
    removal_prob=network_settings.removal_prob,
    addition_prob=network_settings.addition_prob
)
# Out:
# 2025-03-28 14:48:15,381 - INFO - Checking validity...
# 2025-03-28 14:48:15,388 - INFO - Starting data simulations...
# Simulations Progress:   0%|          | 0/2700 [00:00<?, ?it/s]2025-03-28 14:48:15,424 - INFO - Running simulation 1/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 7949.03it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 74.99it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 74.59it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 74.51it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 73.92it/s]
# 2025-03-28 14:48:18,657 - INFO - collecting all words and their counts
# 2025-03-28 14:48:18,658 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:48:18,702 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:48:18,751 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 14:48:18,756 - INFO - Creating a fresh vocabulary
# 2025-03-28 14:48:18,759 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T14:48:18.759821', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:18,761 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T14:48:18.761597', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:18,762 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 14:48:18,763 - INFO - sample=0.001 downsamples 99 most-common words
# 2025-03-28 14:48:18,764 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 242699.38342217568 word corpus (40.4%% of prior 600000)', 'datetime': '2025-03-28T14:48:18.764147', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:18,766 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 14:48:18,770 - INFO - resetting layer weights
# 2025-03-28 14:48:18,776 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T14:48:18.776301', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 14:48:18,777 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T14:48:18.777454', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:19,782 - INFO - EPOCH 0 - PROGRESS: at 68.63% examples, 166447 words/s, in_qsize 1, out_qsize 9
# 2025-03-28 14:48:20,200 - INFO - EPOCH 0: training on 600000 raw words (242846 effective words) took 1.4s, 171209 effective words/s
# 2025-03-28 14:48:21,202 - INFO - EPOCH 1 - PROGRESS: at 74.56% examples, 181135 words/s, in_qsize 3, out_qsize 4
# 2025-03-28 14:48:21,544 - INFO - EPOCH 1: training on 600000 raw words (242487 effective words) took 1.3s, 180726 effective words/s
# 2025-03-28 14:48:22,545 - INFO - EPOCH 2 - PROGRESS: at 74.98% examples, 181718 words/s, in_qsize 7, out_qsize 5
# 2025-03-28 14:48:22,878 - INFO - EPOCH 2: training on 600000 raw words (242506 effective words) took 1.3s, 181966 effective words/s
# 2025-03-28 14:48:23,879 - INFO - EPOCH 3 - PROGRESS: at 74.19% examples, 180394 words/s, in_qsize 7, out_qsize 7
# 2025-03-28 14:48:24,225 - INFO - EPOCH 3: training on 600000 raw words (243276 effective words) took 1.3s, 180775 effective words/s
# 2025-03-28 14:48:25,227 - INFO - EPOCH 4 - PROGRESS: at 74.85% examples, 181670 words/s, in_qsize 4, out_qsize 4
# 2025-03-28 14:48:25,573 - INFO - EPOCH 4: training on 600000 raw words (242571 effective words) took 1.3s, 180093 effective words/s
# 2025-03-28 14:48:25,574 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1213686 effective words) took 6.8s, 178571 effective words/s', 'datetime': '2025-03-28T14:48:25.574441', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:25,574 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T14:48:25.574930', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:   0%|          | 1/2700 [00:10<7:37:53, 10.18s/it]2025-03-28 14:48:25,606 - INFO - Running simulation 2/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 7172.20it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 77.64it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 77.26it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 76.94it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 77.13it/s]
# 2025-03-28 14:48:26,773 - INFO - collecting all words and their counts
# 2025-03-28 14:48:26,773 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:48:26,838 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:48:26,892 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 14:48:26,892 - INFO - Creating a fresh vocabulary
# 2025-03-28 14:48:26,893 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T14:48:26.893371', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:26,893 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T14:48:26.893804', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:26,894 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 14:48:26,895 - INFO - sample=0.001 downsamples 94 most-common words
# 2025-03-28 14:48:26,895 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 240812.923943988 word corpus (40.1%% of prior 600000)', 'datetime': '2025-03-28T14:48:26.895821', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:26,897 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 14:48:26,898 - INFO - resetting layer weights
# 2025-03-28 14:48:26,899 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T14:48:26.899273', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 14:48:26,899 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T14:48:26.899691', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:27,903 - INFO - EPOCH 0 - PROGRESS: at 69.71% examples, 168442 words/s, in_qsize 7, out_qsize 5
# 2025-03-28 14:48:28,240 - INFO - EPOCH 0: training on 600000 raw words (241517 effective words) took 1.3s, 180640 effective words/s
# 2025-03-28 14:48:29,243 - INFO - EPOCH 1 - PROGRESS: at 70.29% examples, 170061 words/s, in_qsize 2, out_qsize 11
# 2025-03-28 14:48:29,634 - INFO - EPOCH 1: training on 600000 raw words (241371 effective words) took 1.4s, 173404 effective words/s
# 2025-03-28 14:48:30,636 - INFO - EPOCH 2 - PROGRESS: at 70.89% examples, 170353 words/s, in_qsize 6, out_qsize 1
# 2025-03-28 14:48:31,029 - INFO - EPOCH 2: training on 600000 raw words (240680 effective words) took 1.4s, 172754 effective words/s
# 2025-03-28 14:48:32,033 - INFO - EPOCH 3 - PROGRESS: at 68.59% examples, 165270 words/s, in_qsize 5, out_qsize 6
# 2025-03-28 14:48:32,521 - INFO - EPOCH 3: training on 600000 raw words (240663 effective words) took 1.5s, 161701 effective words/s
# 2025-03-28 14:48:33,524 - INFO - EPOCH 4 - PROGRESS: at 65.50% examples, 157491 words/s, in_qsize 4, out_qsize 8
# 2025-03-28 14:48:34,083 - INFO - EPOCH 4: training on 600000 raw words (240268 effective words) took 1.6s, 154016 effective words/s
# 2025-03-28 14:48:34,084 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1204499 effective words) took 7.2s, 167661 effective words/s', 'datetime': '2025-03-28T14:48:34.084091', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:34,084 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T14:48:34.084892', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:   0%|          | 2/2700 [00:18<6:54:13,  9.21s/it]2025-03-28 14:48:34,139 - INFO - Running simulation 3/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 7356.75it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 53.84it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 52.64it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 52.64it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 53.12it/s]
# 2025-03-28 14:48:36,152 - INFO - collecting all words and their counts
# 2025-03-28 14:48:36,153 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:48:36,196 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:48:36,243 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 14:48:36,243 - INFO - Creating a fresh vocabulary
# 2025-03-28 14:48:36,244 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T14:48:36.244736', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:36,245 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T14:48:36.245084', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:36,246 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 14:48:36,246 - INFO - sample=0.001 downsamples 100 most-common words
# 2025-03-28 14:48:36,246 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 243396.72023921343 word corpus (40.6%% of prior 600000)', 'datetime': '2025-03-28T14:48:36.246719', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:36,248 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 14:48:36,248 - INFO - resetting layer weights
# 2025-03-28 14:48:36,249 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T14:48:36.249334', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 14:48:36,249 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T14:48:36.249609', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:37,252 - INFO - EPOCH 0 - PROGRESS: at 74.28% examples, 180642 words/s, in_qsize 8, out_qsize 11
# 2025-03-28 14:48:37,591 - INFO - EPOCH 0: training on 600000 raw words (243567 effective words) took 1.3s, 181921 effective words/s
# 2025-03-28 14:48:38,592 - INFO - EPOCH 1 - PROGRESS: at 73.76% examples, 179681 words/s, in_qsize 1, out_qsize 2
# 2025-03-28 14:48:38,951 - INFO - EPOCH 1: training on 600000 raw words (243363 effective words) took 1.4s, 179133 effective words/s
# 2025-03-28 14:48:39,952 - INFO - EPOCH 2 - PROGRESS: at 77.94% examples, 189488 words/s, in_qsize 6, out_qsize 6
# 2025-03-28 14:48:40,226 - INFO - EPOCH 2: training on 600000 raw words (243172 effective words) took 1.3s, 190886 effective words/s
# 2025-03-28 14:48:41,228 - INFO - EPOCH 3 - PROGRESS: at 74.88% examples, 181738 words/s, in_qsize 8, out_qsize 4
# 2025-03-28 14:48:41,576 - INFO - EPOCH 3: training on 600000 raw words (243233 effective words) took 1.3s, 180389 effective words/s
# 2025-03-28 14:48:42,578 - INFO - EPOCH 4 - PROGRESS: at 75.46% examples, 183646 words/s, in_qsize 4, out_qsize 2
# 2025-03-28 14:48:42,934 - INFO - EPOCH 4: training on 600000 raw words (243197 effective words) took 1.4s, 179283 effective words/s
# 2025-03-28 14:48:42,935 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1216532 effective words) took 6.7s, 181967 effective words/s', 'datetime': '2025-03-28T14:48:42.935155', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:42,935 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T14:48:42.935693', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:   0%|          | 3/2700 [00:27<6:46:05,  9.03s/it]2025-03-28 14:48:42,962 - INFO - Running simulation 4/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 7149.58it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 54.46it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 56.70it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 55.26it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 53.66it/s]
# 2025-03-28 14:48:44,343 - INFO - collecting all words and their counts
# 2025-03-28 14:48:44,344 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:48:44,388 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:48:44,431 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 14:48:44,432 - INFO - Creating a fresh vocabulary
# 2025-03-28 14:48:44,433 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T14:48:44.432978', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:44,433 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T14:48:44.433339', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:44,434 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 14:48:44,434 - INFO - sample=0.001 downsamples 96 most-common words
# 2025-03-28 14:48:44,434 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 240809.7096684008 word corpus (40.1%% of prior 600000)', 'datetime': '2025-03-28T14:48:44.434836', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:44,436 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 14:48:44,436 - INFO - resetting layer weights
# 2025-03-28 14:48:44,437 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T14:48:44.437030', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 14:48:44,437 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T14:48:44.437321', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:45,439 - INFO - EPOCH 0 - PROGRESS: at 76.87% examples, 184654 words/s, in_qsize 6, out_qsize 4
# 2025-03-28 14:48:45,740 - INFO - EPOCH 0: training on 600000 raw words (240319 effective words) took 1.3s, 184746 effective words/s
# 2025-03-28 14:48:46,741 - INFO - EPOCH 1 - PROGRESS: at 77.44% examples, 186161 words/s, in_qsize 4, out_qsize 2
# 2025-03-28 14:48:47,035 - INFO - EPOCH 1: training on 600000 raw words (240583 effective words) took 1.3s, 185937 effective words/s
# 2025-03-28 14:48:48,036 - INFO - EPOCH 2 - PROGRESS: at 75.19% examples, 181207 words/s, in_qsize 8, out_qsize 6
# 2025-03-28 14:48:48,357 - INFO - EPOCH 2: training on 600000 raw words (241018 effective words) took 1.3s, 182559 effective words/s
# 2025-03-28 14:48:49,358 - INFO - EPOCH 3 - PROGRESS: at 75.55% examples, 182019 words/s, in_qsize 3, out_qsize 7
# 2025-03-28 14:48:49,673 - INFO - EPOCH 3: training on 600000 raw words (240924 effective words) took 1.3s, 183252 effective words/s
# 2025-03-28 14:48:50,674 - INFO - EPOCH 4 - PROGRESS: at 76.33% examples, 184053 words/s, in_qsize 7, out_qsize 1
# 2025-03-28 14:48:51,001 - INFO - EPOCH 4: training on 600000 raw words (241252 effective words) took 1.3s, 181849 effective words/s
# 2025-03-28 14:48:51,001 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1204096 effective words) took 6.6s, 183430 effective words/s', 'datetime': '2025-03-28T14:48:51.001771', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:51,002 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T14:48:51.002176', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:   0%|          | 4/2700 [00:35<6:28:52,  8.65s/it]2025-03-28 14:48:51,034 - INFO - Running simulation 5/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 7519.37it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 72.42it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 71.89it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 70.94it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 69.92it/s]
# 2025-03-28 14:48:52,328 - INFO - collecting all words and their counts
# 2025-03-28 14:48:52,328 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:48:52,373 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:48:52,418 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 14:48:52,418 - INFO - Creating a fresh vocabulary
# 2025-03-28 14:48:52,419 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T14:48:52.419288', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:52,419 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T14:48:52.419608', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:52,420 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 14:48:52,420 - INFO - sample=0.001 downsamples 97 most-common words
# 2025-03-28 14:48:52,421 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 241728.42378169368 word corpus (40.3%% of prior 600000)', 'datetime': '2025-03-28T14:48:52.421134', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:48:52,422 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 14:48:52,422 - INFO - resetting layer weights
# 2025-03-28 14:48:52,423 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T14:48:52.423356', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 14:48:52,423 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T14:48:52.423880', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:53,425 - INFO - EPOCH 0 - PROGRESS: at 76.03% examples, 183541 words/s, in_qsize 3, out_qsize 4
# 2025-03-28 14:48:53,739 - INFO - EPOCH 0: training on 600000 raw words (241620 effective words) took 1.3s, 183878 effective words/s
# 2025-03-28 14:48:54,741 - INFO - EPOCH 1 - PROGRESS: at 73.72% examples, 178063 words/s, in_qsize 6, out_qsize 8
# 2025-03-28 14:48:55,538 - INFO - EPOCH 1: training on 600000 raw words (241567 effective words) took 1.8s, 134410 effective words/s
# 2025-03-28 14:48:56,549 - INFO - EPOCH 2 - PROGRESS: at 65.66% examples, 158494 words/s, in_qsize 6, out_qsize 11
# 2025-03-28 14:48:57,008 - INFO - EPOCH 2: training on 600000 raw words (241422 effective words) took 1.5s, 165507 effective words/s
# 2025-03-28 14:48:58,009 - INFO - EPOCH 3 - PROGRESS: at 75.70% examples, 182773 words/s, in_qsize 8, out_qsize 8
# 2025-03-28 14:48:58,330 - INFO - EPOCH 3: training on 600000 raw words (241764 effective words) took 1.3s, 183044 effective words/s
# 2025-03-28 14:48:59,331 - INFO - EPOCH 4 - PROGRESS: at 74.94% examples, 181212 words/s, in_qsize 5, out_qsize 3
# 2025-03-28 14:48:59,685 - INFO - EPOCH 4: training on 600000 raw words (241815 effective words) took 1.4s, 178609 effective words/s
# 2025-03-28 14:48:59,686 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1208188 effective words) took 7.3s, 166374 effective words/s', 'datetime': '2025-03-28T14:48:59.685979', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:48:59,686 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T14:48:59.686439', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:   0%|          | 5/2700 [00:44<6:29:04,  8.66s/it]2025-03-28 14:48:59,710 - INFO - Running simulation 6/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 7178.71it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 76.07it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 77.13it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 77.73it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 75.04it/s]
# 2025-03-28 14:49:00,981 - INFO - collecting all words and their counts
# 2025-03-28 14:49:00,982 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:49:01,025 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:49:01,069 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 14:49:01,070 - INFO - Creating a fresh vocabulary
# 2025-03-28 14:49:01,070 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T14:49:01.070780', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:01,071 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T14:49:01.071070', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:01,071 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 14:49:01,072 - INFO - sample=0.001 downsamples 96 most-common words
# 2025-03-28 14:49:01,072 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 241339.9941646938 word corpus (40.2%% of prior 600000)', 'datetime': '2025-03-28T14:49:01.072475', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:01,073 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 14:49:01,074 - INFO - resetting layer weights
# 2025-03-28 14:49:01,074 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T14:49:01.074751', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 14:49:01,075 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T14:49:01.075003', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:49:02,077 - INFO - EPOCH 0 - PROGRESS: at 69.33% examples, 167860 words/s, in_qsize 0, out_qsize 9
# 2025-03-28 14:49:02,475 - INFO - EPOCH 0: training on 600000 raw words (242120 effective words) took 1.4s, 173095 effective words/s
# 2025-03-28 14:49:03,477 - INFO - EPOCH 1 - PROGRESS: at 73.98% examples, 178899 words/s, in_qsize 0, out_qsize 6
# 2025-03-28 14:49:03,833 - INFO - EPOCH 1: training on 600000 raw words (241785 effective words) took 1.4s, 178201 effective words/s
# 2025-03-28 14:49:04,836 - INFO - EPOCH 2 - PROGRESS: at 74.52% examples, 179733 words/s, in_qsize 7, out_qsize 7
# 2025-03-28 14:49:05,179 - INFO - EPOCH 2: training on 600000 raw words (241122 effective words) took 1.3s, 179527 effective words/s
# 2025-03-28 14:49:06,181 - INFO - EPOCH 3 - PROGRESS: at 71.64% examples, 173269 words/s, in_qsize 8, out_qsize 3
# 2025-03-28 14:49:06,609 - INFO - EPOCH 3: training on 600000 raw words (242056 effective words) took 1.4s, 169451 effective words/s
# 2025-03-28 14:49:07,611 - INFO - EPOCH 4 - PROGRESS: at 73.94% examples, 178621 words/s, in_qsize 4, out_qsize 6
# 2025-03-28 14:49:07,952 - INFO - EPOCH 4: training on 600000 raw words (241368 effective words) took 1.3s, 179884 effective words/s
# 2025-03-28 14:49:07,953 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1208451 effective words) took 6.9s, 175686 effective words/s', 'datetime': '2025-03-28T14:49:07.953604', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:49:07,954 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T14:49:07.954209', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:   0%|          | 6/2700 [00:52<6:22:56,  8.53s/it]2025-03-28 14:49:07,979 - INFO - Running simulation 7/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 7653.84it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 78.48it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 77.22it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 77.03it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 78.93it/s]
# 2025-03-28 14:49:09,590 - INFO - collecting all words and their counts
# 2025-03-28 14:49:09,590 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:49:09,642 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:49:09,685 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 14:49:09,686 - INFO - Creating a fresh vocabulary
# 2025-03-28 14:49:09,687 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T14:49:09.687389', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:09,687 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T14:49:09.687889', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:09,688 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 14:49:09,688 - INFO - sample=0.001 downsamples 96 most-common words
# 2025-03-28 14:49:09,689 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 241567.72257803645 word corpus (40.3%% of prior 600000)', 'datetime': '2025-03-28T14:49:09.689277', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:09,690 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 14:49:09,690 - INFO - resetting layer weights
# 2025-03-28 14:49:09,691 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T14:49:09.691206', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 14:49:09,691 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T14:49:09.691463', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:49:10,693 - INFO - EPOCH 0 - PROGRESS: at 75.13% examples, 181947 words/s, in_qsize 8, out_qsize 11
# 2025-03-28 14:49:11,021 - INFO - EPOCH 0: training on 600000 raw words (242021 effective words) took 1.3s, 182216 effective words/s
# 2025-03-28 14:49:12,022 - INFO - EPOCH 1 - PROGRESS: at 76.25% examples, 184683 words/s, in_qsize 3, out_qsize 7
# 2025-03-28 14:49:12,370 - INFO - EPOCH 1: training on 600000 raw words (241851 effective words) took 1.3s, 179437 effective words/s
# 2025-03-28 14:49:13,372 - INFO - EPOCH 2 - PROGRESS: at 74.23% examples, 179307 words/s, in_qsize 0, out_qsize 11
# 2025-03-28 14:49:13,707 - INFO - EPOCH 2: training on 600000 raw words (241145 effective words) took 1.3s, 180661 effective words/s
# 2025-03-28 14:49:14,708 - INFO - EPOCH 3 - PROGRESS: at 74.71% examples, 180343 words/s, in_qsize 4, out_qsize 7
# 2025-03-28 14:49:15,043 - INFO - EPOCH 3: training on 600000 raw words (241719 effective words) took 1.3s, 181109 effective words/s
# 2025-03-28 14:49:16,044 - INFO - EPOCH 4 - PROGRESS: at 75.61% examples, 182654 words/s, in_qsize 4, out_qsize 0
# 2025-03-28 14:49:16,370 - INFO - EPOCH 4: training on 600000 raw words (241639 effective words) took 1.3s, 182313 effective words/s
# 2025-03-28 14:49:16,370 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1208375 effective words) took 6.7s, 180921 effective words/s', 'datetime': '2025-03-28T14:49:16.370569', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:49:16,371 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T14:49:16.370989', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:   0%|          | 7/2700 [01:00<6:21:08,  8.49s/it]2025-03-28 14:49:16,396 - INFO - Running simulation 8/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 3616.81it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 76.68it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 75.44it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 75.32it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 77.46it/s]
# 2025-03-28 14:49:17,635 - INFO - collecting all words and their counts
# 2025-03-28 14:49:17,635 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:49:17,678 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:49:17,722 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 14:49:17,722 - INFO - Creating a fresh vocabulary
# 2025-03-28 14:49:17,723 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T14:49:17.723538', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:17,723 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T14:49:17.723831', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:17,724 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 14:49:17,724 - INFO - sample=0.001 downsamples 96 most-common words
# 2025-03-28 14:49:17,725 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 240823.6627960984 word corpus (40.1%% of prior 600000)', 'datetime': '2025-03-28T14:49:17.725238', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:17,726 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 14:49:17,726 - INFO - resetting layer weights
# 2025-03-28 14:49:17,727 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T14:49:17.727239', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 14:49:17,727 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T14:49:17.727496', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:49:18,729 - INFO - EPOCH 0 - PROGRESS: at 70.16% examples, 168969 words/s, in_qsize 6, out_qsize 4
# 2025-03-28 14:49:19,133 - INFO - EPOCH 0: training on 600000 raw words (241213 effective words) took 1.4s, 171833 effective words/s
# 2025-03-28 14:49:20,135 - INFO - EPOCH 1 - PROGRESS: at 75.44% examples, 181940 words/s, in_qsize 3, out_qsize 4
# 2025-03-28 14:49:20,463 - INFO - EPOCH 1: training on 600000 raw words (241093 effective words) took 1.3s, 181633 effective words/s
# 2025-03-28 14:49:21,465 - INFO - EPOCH 2 - PROGRESS: at 76.74% examples, 184837 words/s, in_qsize 7, out_qsize 7
# 2025-03-28 14:49:21,781 - INFO - EPOCH 2: training on 600000 raw words (240542 effective words) took 1.3s, 182759 effective words/s
# 2025-03-28 14:49:22,782 - INFO - EPOCH 3 - PROGRESS: at 70.75% examples, 170043 words/s, in_qsize 0, out_qsize 10
# 2025-03-28 14:49:23,170 - INFO - EPOCH 3: training on 600000 raw words (240068 effective words) took 1.4s, 172929 effective words/s
# 2025-03-28 14:49:24,172 - INFO - EPOCH 4 - PROGRESS: at 74.59% examples, 180160 words/s, in_qsize 8, out_qsize 1
# 2025-03-28 14:49:24,698 - INFO - EPOCH 4: training on 600000 raw words (241307 effective words) took 1.5s, 158185 effective words/s
# 2025-03-28 14:49:24,698 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1204223 effective words) took 7.0s, 172743 effective words/s', 'datetime': '2025-03-28T14:49:24.698793', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:49:24,699 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T14:49:24.699345', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:   0%|          | 8/2700 [01:09<6:18:46,  8.44s/it]2025-03-28 14:49:24,732 - INFO - Running simulation 9/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 5545.09it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:01<00:00, 45.74it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:01<00:00, 45.05it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:01<00:00, 43.86it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:01<00:00, 43.60it/s]
# 2025-03-28 14:49:26,504 - INFO - collecting all words and their counts
# 2025-03-28 14:49:26,505 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:49:26,552 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:49:26,600 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 14:49:26,600 - INFO - Creating a fresh vocabulary
# 2025-03-28 14:49:26,601 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T14:49:26.601621', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:26,602 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T14:49:26.602070', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:26,603 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 14:49:26,603 - INFO - sample=0.001 downsamples 95 most-common words
# 2025-03-28 14:49:26,603 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 241997.36599206936 word corpus (40.3%% of prior 600000)', 'datetime': '2025-03-28T14:49:26.603854', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 14:49:26,605 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 14:49:26,605 - INFO - resetting layer weights
# 2025-03-28 14:49:26,606 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T14:49:26.606457', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 14:49:26,607 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T14:49:26.607465', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:49:27,615 - INFO - EPOCH 0 - PROGRESS: at 51.78% examples, 125740 words/s, in_qsize 6, out_qsize 1
# 2025-03-28 14:49:28,785 - INFO - EPOCH 0 - PROGRESS: at 80.49% examples, 91969 words/s, in_qsize 8, out_qsize 3
# 2025-03-28 14:49:29,551 - INFO - EPOCH 0: training on 600000 raw words (243020 effective words) took 2.9s, 82749 effective words/s
# 2025-03-28 14:49:30,615 - INFO - EPOCH 1 - PROGRESS: at 47.42% examples, 114800 words/s, in_qsize 5, out_qsize 5
# 2025-03-28 14:49:31,615 - INFO - EPOCH 1 - PROGRESS: at 82.64% examples, 99960 words/s, in_qsize 6, out_qsize 10
# 2025-03-28 14:49:31,978 - INFO - EPOCH 1: training on 600000 raw words (241892 effective words) took 2.4s, 102326 effective words/s
# 2025-03-28 14:49:32,987 - INFO - EPOCH 2 - PROGRESS: at 47.73% examples, 115067 words/s, in_qsize 7, out_qsize 9
# 2025-03-28 14:49:34,023 - INFO - EPOCH 2 - PROGRESS: at 53.98% examples, 64143 words/s, in_qsize 4, out_qsize 8
# 2025-03-28 14:49:35,043 - INFO - EPOCH 2 - PROGRESS: at 62.01% examples, 49365 words/s, in_qsize 5, out_qsize 5
# 2025-03-28 14:49:36,223 - INFO - EPOCH 2 - PROGRESS: at 70.13% examples, 40559 words/s, in_qsize 8, out_qsize 11
# 2025-03-28 14:49:37,168 - INFO - EPOCH 2 - PROGRESS: at 94.38% examples, 44038 words/s, in_qsize 8, out_qsize 0
# 2025-03-28 14:49:37,310 - INFO - EPOCH 2: training on 600000 raw words (241765 effective words) took 5.3s, 45371 effective words/s
# 2025-03-28 14:49:38,322 - INFO - EPOCH 3 - PROGRESS: at 60.08% examples, 145256 words/s, in_qsize 7, out_qsize 4
# 2025-03-28 14:49:39,010 - INFO - EPOCH 3: training on 600000 raw words (242089 effective words) took 1.7s, 143355 effective words/s
# 2025-03-28 14:49:40,016 - INFO - EPOCH 4 - PROGRESS: at 58.19% examples, 141148 words/s, in_qsize 7, out_qsize 3
# 2025-03-28 14:49:40,835 - INFO - EPOCH 4: training on 600000 raw words (242001 effective words) took 1.8s, 132959 effective words/s
# 2025-03-28 14:49:40,839 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1210767 effective words) took 14.2s, 85081 effective words/s', 'datetime': '2025-03-28T14:49:40.839327', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 14:49:40,840 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T14:49:40.840759', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:   0%|          | 9/2700 [01:25<8:10:46, 10.94s/it]2025-03-28 14:49:41,192 - INFO - Running simulation 10/100 for random, barabasi_albert_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 4660.70it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:01<00:00, 36.78it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:01<00:00, 34.85it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:01<00:00, 33.51it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:01<00:00, 33.37it/s]
# 2025-03-28 14:49:44,077 - INFO - collecting all words and their counts
# 2025-03-28 14:49:44,080 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 14:49:44,164 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 14:49:44,233 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# ...
# 2025-03-28 18:52:52,391 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T18:52:52.391687', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:  15%|█▍        | 404/2700 [4:04:37<9:25:36, 14.78s/it]2025-03-28 18:52:52,624 - INFO - Running simulation 5/100 for random, watts_strogatz_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 25132.15it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:01<00:00, 33.37it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:01<00:00, 31.96it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:01<00:00, 30.43it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:02<00:00, 23.55it/s]
# 2025-03-28 18:52:55,467 - INFO - collecting all words and their counts
# 2025-03-28 18:52:55,469 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 18:52:55,569 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 18:52:55,641 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 18:52:55,642 - INFO - Creating a fresh vocabulary
# 2025-03-28 18:52:55,646 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T18:52:55.646428', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 18:52:55,647 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T18:52:55.647836', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 18:52:55,649 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 18:52:55,650 - INFO - sample=0.001 downsamples 100 most-common words
# 2025-03-28 18:52:55,651 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 244631.8695338665 word corpus (40.8%% of prior 600000)', 'datetime': '2025-03-28T18:52:55.651259', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 18:52:55,654 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 18:52:55,655 - INFO - resetting layer weights
# 2025-03-28 18:52:55,657 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T18:52:55.657273', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 18:52:55,658 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T18:52:55.658040', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 18:52:56,665 - INFO - EPOCH 0 - PROGRESS: at 42.07% examples, 102805 words/s, in_qsize 5, out_qsize 2
# 2025-03-28 18:52:57,664 - INFO - EPOCH 0 - PROGRESS: at 80.59% examples, 98446 words/s, in_qsize 7, out_qsize 5
# 2025-03-28 18:52:58,239 - INFO - EPOCH 0: training on 600000 raw words (244157 effective words) took 2.6s, 94829 effective words/s
# 2025-03-28 18:52:59,282 - INFO - EPOCH 1 - PROGRESS: at 42.06% examples, 102870 words/s, in_qsize 6, out_qsize 1
# 2025-03-28 18:53:00,282 - INFO - EPOCH 1 - PROGRESS: at 96.52% examples, 118051 words/s, in_qsize 7, out_qsize 0
# 2025-03-28 18:53:00,357 - INFO - EPOCH 1: training on 600000 raw words (244616 effective words) took 2.1s, 117757 effective words/s
# 2025-03-28 18:53:01,360 - INFO - EPOCH 2 - PROGRESS: at 54.02% examples, 131926 words/s, in_qsize 5, out_qsize 2
# 2025-03-28 18:53:02,362 - INFO - EPOCH 2 - PROGRESS: at 83.75% examples, 102430 words/s, in_qsize 6, out_qsize 1
# 2025-03-28 18:53:03,074 - INFO - EPOCH 2: training on 600000 raw words (244829 effective words) took 2.7s, 90201 effective words/s
# 2025-03-28 18:53:04,085 - INFO - EPOCH 3 - PROGRESS: at 62.66% examples, 153239 words/s, in_qsize 4, out_qsize 3
# 2025-03-28 18:53:04,768 - INFO - EPOCH 3: training on 600000 raw words (244643 effective words) took 1.7s, 145251 effective words/s
# 2025-03-28 18:53:05,774 - INFO - EPOCH 4 - PROGRESS: at 44.56% examples, 109215 words/s, in_qsize 7, out_qsize 2
# 2025-03-28 18:53:06,774 - INFO - EPOCH 4 - PROGRESS: at 62.33% examples, 76346 words/s, in_qsize 7, out_qsize 0
# 2025-03-28 18:53:07,484 - INFO - EPOCH 4: training on 600000 raw words (244961 effective words) took 2.7s, 90353 effective words/s
# 2025-03-28 18:53:07,488 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1223206 effective words) took 11.8s, 103398 effective words/s', 'datetime': '2025-03-28T18:53:07.488526', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 18:53:07,490 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T18:53:07.489983', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:  15%|█▌        | 405/2700 [4:04:52<9:27:26, 14.84s/it]2025-03-28 18:53:07,585 - INFO - Running simulation 6/100 for random, watts_strogatz_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 24078.90it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:01<00:00, 26.35it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:03<00:00, 12.59it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:04<00:00, 12.42it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:04<00:00, 12.45it/s]
# 2025-03-28 18:53:12,504 - INFO - collecting all words and their counts
# 2025-03-28 18:53:12,512 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 18:53:12,607 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 18:53:12,700 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 18:53:12,703 - INFO - Creating a fresh vocabulary
# 2025-03-28 18:53:12,706 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T18:53:12.706622', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 18:53:12,708 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T18:53:12.708215', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 18:53:12,714 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 18:53:12,716 - INFO - sample=0.001 downsamples 100 most-common words
# 2025-03-28 18:53:12,716 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 245698.69719663885 word corpus (40.9%% of prior 600000)', 'datetime': '2025-03-28T18:53:12.716911', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 18:53:12,731 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 18:53:12,736 - INFO - resetting layer weights
# 2025-03-28 18:53:12,750 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T18:53:12.750671', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 18:53:12,753 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T18:53:12.753597', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 18:53:13,823 - INFO - EPOCH 0 - PROGRESS: at 46.84% examples, 114941 words/s, in_qsize 7, out_qsize 1
# 2025-03-28 18:53:14,823 - INFO - EPOCH 0 - PROGRESS: at 85.36% examples, 104764 words/s, in_qsize 6, out_qsize 1
# 2025-03-28 18:53:15,346 - INFO - EPOCH 0: training on 600000 raw words (245451 effective words) took 2.5s, 97265 effective words/s
# 2025-03-28 18:53:16,350 - INFO - EPOCH 1 - PROGRESS: at 36.80% examples, 90391 words/s, in_qsize 7, out_qsize 2
# 2025-03-28 18:53:17,350 - INFO - EPOCH 1 - PROGRESS: at 60.09% examples, 73677 words/s, in_qsize 1, out_qsize 6
# 2025-03-28 18:53:18,045 - INFO - EPOCH 1: training on 600000 raw words (245265 effective words) took 2.7s, 90982 effective words/s
# 2025-03-28 18:53:19,059 - INFO - EPOCH 2 - PROGRESS: at 62.50% examples, 153528 words/s, in_qsize 5, out_qsize 1
# 2025-03-28 18:53:19,981 - INFO - EPOCH 2: training on 600000 raw words (245703 effective words) took 1.9s, 127834 effective words/s
# 2025-03-28 18:53:20,985 - INFO - EPOCH 3 - PROGRESS: at 61.65% examples, 151394 words/s, in_qsize 6, out_qsize 3
# 2025-03-28 18:53:21,552 - INFO - EPOCH 3: training on 600000 raw words (246083 effective words) took 1.6s, 157012 effective words/s
# 2025-03-28 18:53:22,561 - INFO - EPOCH 4 - PROGRESS: at 56.62% examples, 139056 words/s, in_qsize 7, out_qsize 3
# 2025-03-28 18:53:23,515 - INFO - EPOCH 4: training on 600000 raw words (246105 effective words) took 2.0s, 125831 effective words/s
# 2025-03-28 18:53:23,519 - INFO - Word2Vec lifecycle event {'msg': 'training on 3000000 raw words (1228607 effective words) took 10.8s, 114205 effective words/s', 'datetime': '2025-03-28T18:53:23.518167', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 18:53:23,521 - INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=100, vector_size=64, alpha=0.025>', 'datetime': '2025-03-28T18:53:23.521356', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'created'}
# Simulations Progress:  15%|█▌        | 406/2700 [4:05:08<9:41:56, 15.22s/it]2025-03-28 18:53:23,705 - INFO - Running simulation 7/100 for random, watts_strogatz_graph, influence 0.8999999999999999
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 16097.89it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 64.35it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 52.71it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 50.38it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:01<00:00, 43.99it/s]
# 2025-03-28 18:53:26,472 - INFO - collecting all words and their counts
# 2025-03-28 18:53:26,480 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-03-28 18:53:26,604 - INFO - PROGRESS: at sentence #10000, processed 300000 words, keeping 100 word types
# 2025-03-28 18:53:26,690 - INFO - collected 100 word types from a corpus of 600000 raw words and 20000 sentences
# 2025-03-28 18:53:26,692 - INFO - Creating a fresh vocabulary
# 2025-03-28 18:53:26,694 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 100 unique words (100.00% of original 100, drops 0)', 'datetime': '2025-03-28T18:53:26.693747', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 18:53:26,694 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 600000 word corpus (100.00% of original 600000, drops 0)', 'datetime': '2025-03-28T18:53:26.694976', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 18:53:26,700 - INFO - deleting the raw counts dictionary of 100 items
# 2025-03-28 18:53:26,701 - INFO - sample=0.001 downsamples 100 most-common words
# 2025-03-28 18:53:26,702 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 244141.88027172693 word corpus (40.7%% of prior 600000)', 'datetime': '2025-03-28T18:53:26.702863', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2025-03-28 18:53:26,707 - INFO - estimated required memory for 100 words and 64 dimensions: 101200 bytes
# 2025-03-28 18:53:26,708 - INFO - resetting layer weights
# 2025-03-28 18:53:26,716 - INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-03-28T18:53:26.715993', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2025-03-28 18:53:26,717 - INFO - Word2Vec lifecycle event {'msg': 'training model with 4 workers on 100 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2025-03-28T18:53:26.717076', 'gensim': '4.3.3', 'python': '3.12.6 (main, Sep 16 2024, 19:20:48) [Clang 12.0.5 (clang-1205.0.22.11)]', 'platform': 'macOS-15.3.1-x86_64-i386-64bit', 'event': 'train'}
# 2025-03-28 18:53:27,727 - INFO - EPOCH 0 - PROGRESS: at 38.60% examples, 94306 words/s, in_qsize 0, out_qsize 10
# 2025-03-28 18:53:28,729 - INFO - EPOCH 0 - PROGRESS: at 64.64% examples, 78856 words/s, in_qsize 2, out_qsize 2
# 2025-03-28 18:53:29,617 - INFO - EPOCH 0: training on 600000 raw words (244153 effective words) took 2.9s, 84548 effective words/s
# 2025-03-28 18:53:30,627 - INFO - EPOCH 1 - PROGRESS: at 41.20% examples, 100937 words/s, in_qsize 5, out_qsize 1
# 2025-03-28 18:53:31,593 - INFO - EPOCH 1: training on 600000 raw words (244302 effective words) took 2.0s, 124266 effective words/s
# 2025-03-28 18:53:32,597 - INFO - EPOCH 2 - PROGRESS: at 51.97% examples, 126893 words/s, in_qsize 7, out_qsize 1
# 2025-03-28 18:53:33,598 - INFO - EPOCH 2 - PROGRESS: at 90.78% examples, 110809 words/s, in_qsize 2, out_qsize 3
# 2025-03-28 18:53:33,817 - INFO - EPOCH 2: training on 600000 raw words (244279 effective words) took 2.2s, 109954 effective words/s
# 2025-03-28 18:53:34,824 - INFO - EPOCH 3 - PROGRESS: at 32.81% examples, 79973 words/s, in_qsize 6, out_qsize 2
# 2025-03-28 18:53:35,827 - INFO - EPOCH 3 - PROGRESS: at 65.48% examples, 79860 words/s, in_qsize 8, out_qsize 0
# 2025-03-28 18:53:36,826 - INFO - EPOCH 3 - PROGRESS: at 83.22% examples, 67758 words/s, in_qsize 5, out_qsize 8
